# %% [markdown]
# ## Notebook Description
#
# This notebook processes audio datasets by extracting embeddings using the **Birdnetlib library** and saving the results to CSV files. It is designed to handle multiple bird species datasets and ensures efficient processing with memory management and progress tracking.
#
# ### **Main Tasks:**
#
# 1. **Load and Organize Audio Files:**
#    - Dynamically retrieves `.wav` audio files from the Extended_audios directory for the following datasets:
#      - `chiffchaff-fg`
#      - `littleowl-fg`
#      - `pipit-fg`
#      - `rtbc-begging`
#      - `littlepenguin-display_call-exhale`
#      - `greatTit_song-files`
#      - `KiwiTrimmed`
#    - Prints the number of audio files found for each dataset and verifies the first few file paths.
#
# 2. **Set Up Output Directory and CSV Files:**
#    - Creates an output directory (Embeddings_from_3sPadding) if it does not exist.
#    - Defines separate CSV files for each dataset to store the extracted embeddings.
#
# 3. **Extract Embeddings Using BirdNET:**
#    - Initializes the BirdNET model (`Analyzer`).
#    - Iterates through the audio files, skipping already processed files (tracked in the CSV).
#    - For each audio file:
#      - Loads the file into BirdNET.
#      - Extracts embeddings and metadata (e.g., start time, end time).
#      - Saves the embeddings to the corresponding CSV file in batches of 200 files to optimize memory usage.
#
# 4. **Handle Errors and Memory Management:**
#    - Skips files that cannot be processed and logs errors.
#    - Clears memory after processing each batch to ensure efficient execution.
#
# 5. **Post-Processing Analysis:**
#    - Compares the original list of audio files with the processed files in the CSV.
#    - Reports the total number of processed, unprocessed, and skipped files.
#    - Displays a list of unprocessed audio files for further investigation.
#
# ### **Output:**
# - CSV files containing embeddings for each dataset, saved in the directory:
#   ```
#   Output_files/Embeddings_from_3sPadding/
#   ```
#   Example:  `greatTit_embeddings.csv`, etc.
#
# ### **Key Features:**
# - Efficient batch processing with progress updates every 200 files.
# - Skips already processed files to avoid duplication.
# - Handles large datasets with memory management and error handling.
# - Provides detailed statistics on processed and unprocessed files.
#
# This notebook ensures that audio embeddings are extracted and saved efficiently, making the datasets ready for further analysis or machine learning workflows.

# %%
import csv
import pandas as pd
from pathlib import Path
import gc
import soundfile as sf
import numpy as np
import glob
from birdnetlib import Recording
from birdnetlib.analyzer import Analyzer
import os
import ipywidgets as widgets
from IPython.display import display

# Get the current working directory
cwd = Path.cwd()
project_root = cwd.parents[1]
#Path base
base_path = project_root / 'Output_files' / 'Extended_audios'
# Create the output directory for embeddings
output_dir = project_root / 'Output_files' / 'Embeddings_from_3sPadding'
output_dir.mkdir(parents=True, exist_ok=True)


#Function to dynamically retrieve .wav files
def get_audio_files(base_path, folder_name, pattern="**/*.[Ww][Aa][Vv]"):
    return glob.glob(f"{str(base_path)}/{folder_name}/{pattern}", recursive=True)


#Use the function to get audio files for each bird species
audios_chiffchaff = get_audio_files(base_path, "chiffchaff-fg")
audios_littleowl = get_audio_files(base_path, "littleowl-fg")
audios_pipit = get_audio_files(base_path, "pipit-fg")
audios_rtbc = get_audio_files(base_path, "rtbc-begging")
audios_littlepenguin = get_audio_files(base_path, "littlepenguin-display_call-exhale")
audios_greatTit = get_audio_files(base_path, "greatTit_song-files")
audios_kiwi = get_audio_files(base_path, "KiwiTrimmed")


# Define the CSV files for each dataset
csv_chiffchaff = output_dir / 'chiffchaff_embeddings.csv'
csv_littleowl = output_dir / 'littleowl_embeddings.csv'
csv_pipit = output_dir / 'pipit_embeddings.csv'
csv_rtbc = output_dir / 'rtbc_embeddings.csv'
csv_littlepenguin = output_dir / 'littlepenguin_embeddings.csv'
csv_greatTit = output_dir / 'greatTit_embeddings.csv'
csv_kiwi = output_dir / 'kiwi_embeddings.csv'


# Dataset mapping
dataset_map = {
    "chiffchaff-fg": (audios_chiffchaff, csv_chiffchaff),
    "littleowl-fg": (audios_littleowl, csv_littleowl),
    "pipit-fg": (audios_pipit, csv_pipit),
    "rtbc-begging": (audios_rtbc, csv_rtbc),
    "littlepenguin-display_call-exhale": (audios_littlepenguin, csv_littlepenguin),
    "greatTit_song-files": (audios_greatTit, csv_greatTit),
    "KiwiTrimmed": (audios_kiwi, csv_kiwi) 
}

# Create dropdown with initial value None
dataset_dropdown = widgets.Dropdown(
    options=[('Select a dataset', None)] + [(k, k) for k in dataset_map.keys()],
    description='Select dataset:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%'),
    #value=None  # 
)

# Callback function
def on_selection_change(change):
    if change['new'] is not None:
        global audios, csv_filename
        selected_key = change['new']
        audios, csv_filename = dataset_map[selected_key]
        print(f"\nSelected: {selected_key}")
        print(f"Total audio files: {len(audios)}")
        print(f"CSV output file: {csv_filename.name}")

# Observe changes
dataset_dropdown.observe(on_selection_change, names='value')

# Display the dropdown
display(dataset_dropdown)
# Out:
# Dropdown(description='Select dataset:', layout=Layout(width='50%'), options=(('Select a dataset', None), ('chi…
# Selected: KiwiTrimmed
# Total audio files: 455
# CSV output file: kiwi_embeddings.csv

# %%
# Make sure audios and csv_filename were defined
try:
    # Check if the CSV file already exists
    if os.path.exists(csv_filename):
        df_embeddings = pd.read_csv(csv_filename)
        if "file_name" in df_embeddings.columns:
            processed_files = set(df_embeddings["file_name"].unique())
        else:
            processed_files = set()
    else:
        df_embeddings = pd.DataFrame()
        processed_files = set()

    # Extract filenames from paths
    original_audios = set(Path(audio).name for audio in audios)
    unprocessed_audios = original_audios - processed_files

    # Display results
    print(f"Total audios in the original list: {len(original_audios)}")
    print(f"Total audios already processed: {len(processed_files)}")
    print(f"Total audios not yet processed: {len(unprocessed_audios)}")

except NameError:
    print("❌ Please run the dataset selection cell first.")
# Out:
# Total audios in the original list: 455
# Total audios already processed: 0
# Total audios not yet processed: 455

# %%
# Check that required variables are defined (from the selection cell)
if "audios" not in globals() or "csv_filename" not in globals():
    raise RuntimeError("❌ 'audios' and 'csv_filename' are not defined. Please run the dataset selection cell first.")

if len(unprocessed_audios) > 0: 
    # Initialize the BirdNET model
    analyzer = Analyzer()

    # Check if the CSV file already exists to retrieve processed audio files
    if os.path.exists(csv_filename):
        df_existing = pd.read_csv(csv_filename)
        processed_files = set(df_existing["file_name"])  # Already processed files
    else:
        processed_files = set()

    # List of audio file paths
    all_data = []
    processed_count = 0  # Counter for files processed in this execution
    batch_size = 200     # Save after every 200 audios

    # Iterate through each file in the list of audio files
    for audio_path in audios:
        try:
            # Extract the file name without the path
            file_name = os.path.basename(audio_path)

            # Skip if the file has already been processed
            if file_name in processed_files:
                continue

            # Load the recording into BirdNET
            recording = Recording(analyzer, audio_path)
            # Extract embeddings
            recording.extract_embeddings()

            # Process the extracted embeddings
            for emb in recording.embeddings:
                row = {
                    "file_name": file_name,
                    "start_time": emb['start_time'],
                    "end_time": emb['end_time']
                }
                for i, value in enumerate(emb["embeddings"]):
                    row[f"dim_{i+1}"] = value

                all_data.append(row)

            processed_count += 1

            # Save every batch_size audios
            if processed_count % batch_size == 0:
                df_partial = pd.DataFrame(all_data)
                df_partial.to_csv(csv_filename, mode='a', header=not os.path.exists(csv_filename), index=False)
                all_data = []
                print(f"{processed_count} audios processed and saved.")

            # Clear memory
            del recording
            gc.collect()

        except Exception as e:
            print(f"Error processing {audio_path}: {e}")

    # Save remaining data at the end
    if all_data:
        df_partial = pd.DataFrame(all_data)
        df_partial.to_csv(csv_filename, mode='a', header=not os.path.exists(csv_filename), index=False)
        print(f"Saved remaining {len(all_data)} entries.")

    print(f"Embeddings saved to {csv_filename}")
else:
    print("✅ All audio files have already been processed. No new files to process.")
    print(f"Embeddings saved to {csv_filename}")
# Out:
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121217_222458_125-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121229_233001_185-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121103_213004_0-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121223_214502_326-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121221_213002_623-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121228_214502_351-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121110_024503_448-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121222_213002_829-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121205_224501_667-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121209_214502_535-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121215_223002_163-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121111_035218_441-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121108_223004_828-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121225_221502_181-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121105_003003_166-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121107_213004_604-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121105_221504_770-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121215_214502_219-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121101_214504_375-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121110_211504_835-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141228_005950_26-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141228_215959_299-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20150105_024445_423-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201213_20130329_200002_630-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141217_224457_760-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20150125_021501_583-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201213_20130330_200002_791-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20150114_221503_296-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141221_213001_620-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141228_213001_207-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201213_20130321_211502_228-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141222_214500_265-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201213_20130322_203002_97-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141228_011449_706-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20150105_022945_47-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20130926_024500_30-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20131107_040001_234-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20140905_023001_607-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20131113_030001_503-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20141015_033001_521-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20141031_230003_737-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20141031_030001_172-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20141019_031501_814-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20141018_040001_710-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20130927_033000_713-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20140829_033000_660-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201415_20140907_024501_174-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20131108_013002_393-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201213_20121031_200007_5906-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20130925_034500_449-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-ClydeNest201314_20131114_023001_595-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141003_011502_784-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141011_021502_816-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141002_003002_560-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141001_014502_367-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141005_004502_447-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140930_001501_0-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141004_201503_222-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140921_210002_520-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140919_021501_380-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140925_020001_371-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140921_000001_121-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141007_030001_296-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141009_033001_683-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141013_201503_429-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140923_004501_446-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20141012_021502_229-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140929_001501_807-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-HerbNest201415_20140923_233002_562-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_10_17_2_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_10_16_1_03_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 4_2020_10_9_20_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 5_2020_10_25_2_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_28_21_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 4_2020_10_2_1_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 5_2020_10_26_4_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 4_2020_10_3_2_21_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_10_16_1_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 4_2020_10_6_2_11_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 3_2020_10_22_5_48_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 5_2020_10_26_4_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 4_2020_10_7_1_47_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 1_2020_12_14_1_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_18_3_16_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_17_2_15_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 1_2020_12_15_21_59_trim.wav
# read_audio_data
# read_audio_data: complete, read  6 chunks.
# extract_embeddings_for_recording 1_2020_12_16_4_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_10_3_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  5 chunks.
# extract_embeddings_for_recording 1_2020_12_4_2_41_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_9_1_40_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131112_023234_773-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131113_044435_754-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131111_025941_531-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131111_011446_29-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131011_042935_575-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131004_234450_599-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131103_234451_498-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-Bazza&ShazzaTerr_20121031_200000_19567-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131003_215956_500-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131009_222954_37-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  14 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131105_010255_126-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131109_030241_592-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131106_050035_339-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131009_224453_835-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131110_222955_706-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131003_232951_613-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131005_021443_791-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-Bazza&ShazzaTerr_20121101_200000_21477-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  14 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131007_025940_138-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131002_012945_543-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BazzaNest201314_20131109_044736_536-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131223_043001_147-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131228_030001_92-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121127_000001_168-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  14 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121115_031501_739-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131218_050001_477-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121126_014957_303-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131221_041501_199-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121117_003001_444-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131227_053001_327-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131224_024501_105-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121122_013001_75-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131222_040001_491-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121118_001501_220-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 9_2020_11_12_2_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 9_2020_11_13_4_54_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_10_8_1_38_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 11_2020_10_7_21_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2021_1_8_23_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_6_21_46_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_13_1_25_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 9_2020_11_15_0_56_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 8_2020_10_22_22_37_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 7_2020_10_5_0_49_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_15_2_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_25_4_32_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_12_22_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2021_1_8_22_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 7_2020_10_5_1_40_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_6_1_41_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_15_23_36_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_10_9_4_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_10_13_21_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2021_1_8_0_01_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 4_2020_10_21_3_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_12_27_2_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_12_30_22_33_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_10_3_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 3_2020_10_2_4_36_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 7_2020_10_5_3_11_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_12_31_0_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_10_9_22_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 9_2020_11_6_3_20_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2021_1_11_22_20_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 6_2020_10_24_1_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2021_1_4_22_44_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 9_2020_10_29_21_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 4_2020_10_26_5_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 7_2020_10_12_22_10_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_10_2_22_58_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 9_2020_11_13_23_43_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 12_2020_10_19_3_50_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_11_21_27_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_10_3_21_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 11_2020_9_30_21_43_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_16_4_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 9_2020_11_8_22_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 10_2020_10_14_21_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 10_2020_10_15_21_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 7_2020_10_4_22_12_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_10_1_1_58_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_25_3_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_10_3_1_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 11_2020_10_12_2_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 9_2020_11_11_22_38_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_29_4_42_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 7_2020_10_8_2_32_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 8_2020_10_29_3_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130929_200002_217-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130928_193002_678-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130925_231502_477-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20131002_214502_809-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130927_221502_742-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130924_201502_347-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20131004_200002_361-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20130923_224502_237-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-BerryNest201314_20131002_013001_328-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121124_024501_699-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121229_044501_324-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121219_041501_117-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121222_034501_672-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121201_034500_507-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121227_033001_73-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121126_030001_440-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121123_003001_729-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121225_040001_106-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121125_044500_81-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121127_034501_229-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121223_030001_419-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121122_043000_150-GSKfemale_trim.wav
# 200 audios processed and saved.
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121221_031501_569-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_13_3_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_11_24_21_48_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 7_2020_10_15_0_17_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_10_31_2_56_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 7_2020_10_16_2_06_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_18_1_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_26_23_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_11_24_23_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_10_2_6_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording 3_2020_12_15_22_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 6_2020_10_22_1_45_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_21_0_30_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_2_20_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 7_2020_10_25_2_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 5_2020_11_8_2_56_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 4_2020_10_15_22_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 6_2020_10_16_1_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 7_2020_10_25_3_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 4_2020_10_20_22_14_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_13_23_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_12_16_22_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_12_2_15_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 3_2020_11_29_1_32_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_2_22_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_22_2_46_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 6_2020_10_23_1_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_10_21_56_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_10_1_20_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_3_5_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_5_23_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_17_22_49_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 3_2020_11_30_1_15_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_22_0_60_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_16_23_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 5_2020_11_7_21_30_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_15_3_10_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_20_23_31_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_14_2_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_15_2_54_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_7_2_26_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_20_22_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_12_15_1_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_10_30_22_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_11_30_2_16_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_10_14_3_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_10_14_22_33_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_7_22_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_6_22_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_16_0_29_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_14_0_21_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_10_13_21_10_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_4_4_21_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 3_2020_12_21_1_58_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 5_2020_11_13_4_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 5_2020_11_4_21_49_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_12_23_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 2_2020_10_24_0_36_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_10_10_3_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 6_2020_10_20_21_09_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_9_30_0_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_9_0_54_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_11_30_0_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_14_23_46_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_10_23_3_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording 2_2020_10_14_5_47_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_20_22_12_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_10_10_2_53_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_10_16_23_49_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_10_31_3_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_2_1_22_trim.wav
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording 3_2020_11_22_2_06_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_4_0_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_3_2_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 4_2020_10_24_2_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_10_22_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_5_20_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_12_1_22_10_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_18_0_39_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_11_30_3_27_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_9_22_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_5_2_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_12_4_23_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_3_20_56_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_9_30_21_41_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_9_23_27_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 5_2020_11_8_23_38_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_28_3_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 3_2020_12_4_22_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_10_23_53_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 5_2020_11_11_22_39_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_29_23_14_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_10_10_20_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_28_2_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_10_18_4_03_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 2_2020_10_25_0_17_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_13_22_34_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 6_2020_10_21_2_03_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 2_2020_10_26_21_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_10_22_22_42_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_28_1_26_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_24_22_33_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_3_22_08_trim.wav
# read_audio_data
# read_audio_data: complete, read  5 chunks.
# extract_embeddings_for_recording 6_2020_10_24_3_15_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 3_2020_12_19_22_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_11_19_2_33_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_20_3_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 5_2020_10_31_21_41_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 5_2020_11_13_2_27_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_12_15_0_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_10_28_22_26_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 3_2020_11_19_22_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_10_4_2_48_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 6_2020_10_20_23_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_10_2_21_26_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_12_26_3_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_29_22_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_20_1_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_12_19_0_46_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 1_2020_12_13_22_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_14_0_58_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_15_2_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 2_2020_12_17_1_52_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_16_3_23_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_11_1_46_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_22_22_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_13_23_09_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording 1_2021_1_8_3_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_15_3_30_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_18_22_59_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2021_1_8_2_59_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_18_2_20_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_30_0_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_10_22_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2021_1_1_0_38_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_14_23_32_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 2_2020_12_19_4_20_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_16_4_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2021_1_12_0_14_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_15_0_36_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_16_2_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_20_2_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 2_2020_12_19_23_47_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 2_2020_12_19_2_39_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2021_1_11_22_20_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_12_16_0_59_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_29_3_12_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2021_1_5_4_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_31_22_24_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_17_22_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_15_4_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121103_044501_46-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121104_004502_221-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121102_013002_664-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121030_023002_750-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201415_20150114_021502_138-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121106_024502_361-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121031_044501_358-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121109_013002_149-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121105_020001_547-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121229_021501_233-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121228_214502_790-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121102_224502_767-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121102_033001_729-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121108_004503_6-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121101_014502_432-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-RangiNest201213_20121031_004502_219-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141220_015946_248-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141226_012948_599-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141231_014447_729-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141222_232954_551-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141225_232955_672-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141231_025943_740-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141225_031443_652-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141218_031443_375-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141227_214500_684-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-MakNest201415_20141224_014447_18-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_12_8_23_10_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_19_1_22_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_11_27_22_27_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording 2_2020_11_23_21_39_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_4_1_06_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 2_2020_11_25_1_14_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_10_2_26_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_24_22_35_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_19_0_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_18_1_51_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 2_2020_12_16_0_11_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_11_26_22_49_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_14_23_18_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_16_3_21_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 1_2020_11_30_2_38_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_11_25_2_57_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_12_1_54_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_4_23_04_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_25_0_50_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_19_2_47_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 1_2020_12_14_2_12_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_10_0_07_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_11_29_2_41_trim.wav
# 400 audios processed and saved.
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_2_0_25_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_23_0_02_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_11_26_21_48_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_23_22_39_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_21_1_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_11_27_2_55_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_11_22_22_19_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_12_3_2_25_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 1_2020_12_20_22_14_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_12_16_23_13_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121229_023001_388-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121103_044503_423-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121225_031501_650-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121111_023126_178-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121101_030002_452-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121104_040002_497-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121102_024503_0-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121108_021503_786-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121110_044503_814-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-EbbNest201213_20121107_024503_606-GSKfemale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording 3_2020_10_2_1_03_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_10_23_22_33_trim.wav
# read_audio_data
# read_audio_data: complete, read  13 chunks.
# extract_embeddings_for_recording 4_2020_10_7_22_37_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 1_2020_10_26_2_59_trim.wav
# read_audio_data
# read_audio_data: complete, read  7 chunks.
# extract_embeddings_for_recording 4_2020_10_10_3_05_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording 3_2020_10_8_23_44_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 2_2020_11_18_2_42_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 1_2020_10_23_3_28_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording 3_2020_10_3_20_32_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121128_030001_602-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121224_223002_460-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121228_043001_688-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121229_000001_425-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121125_213002_375-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121122_000001_382-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121123_221502_714-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121202_040927_490-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121130_214502_682-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121128_224502_258-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121121_043000_121-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  12 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121126_043000_551-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-AdamNest201213_20121220_214502_278-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  11 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131223_220002_166-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121117_214502_140-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131226_050000_758-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131225_233002_467-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121113_233001_329-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131225_044501_57-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131221_220002_615-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  9 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131222_214502_643-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131225_021501_698-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  10 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121116_220002_16-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131220_230002_557-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201213_20121118_030001_514-GSKmale_trim.wav
# read_audio_data
# read_audio_data: complete, read  8 chunks.
# extract_embeddings_for_recording Hawdon-MossNest201314_20131227_233002_571-GSKmale_trim.wav
# Saved remaining 529 entries.
# Embeddings saved to /teamspace/studios/this_studio/Output_files/Embeddings_from_3sPadding/kiwi_embeddings.csv

# %%
# Check if the CSV file already exists to retrieve processed audio files
if os.path.exists(csv_filename):
    df_embeddings = pd.read_csv(csv_filename)
    processed_files = set(df_embeddings["file_name"])  # Already processed files
else:
    df_embeddings = pd.DataFrame()
    processed_files = set()
 
#original_audios = set(audios) # Convert the original list of audios to a set,
original_audios = set(Path(audio).name for audio in audios) # Convert the original list of audios to a set,
processed_audios = set(df_embeddings["file_name"].unique()) # Get the list of processed audios from the DataFrame
unprocessed_audios = original_audios - processed_audios # Identify the audios that were not processed

# Display results
print(f"Total audios processed: {len(processed_audios)}")
print(f"Total audios not processed: {len(unprocessed_audios)}")

#Audios that were not processed:
print("Unprocessed audios:")
print("\n".join(unprocessed_audios))

print("structure of the DataFrame:")
print(df_embeddings.head() if not df_embeddings.empty else "DataFrame is empty.")
#print(df_embeddings.head())  # Display the first few rows of the DataFrame
# Clean up memory
del df_embeddings
# Out:
# Total audios processed: 455
# Total audios not processed: 0
# Unprocessed audios:
#
# structure of the DataFrame:
#                                            file_name  start_time  end_time  \
# 0  Hawdon-EbbNest201213_20121217_222458_125-GSKma...         0.0       3.0
# 1  Hawdon-EbbNest201213_20121217_222458_125-GSKma...         3.0       6.0
# 2  Hawdon-EbbNest201213_20121217_222458_125-GSKma...         6.0       9.0
# 3  Hawdon-EbbNest201213_20121217_222458_125-GSKma...         9.0      12.0
# 4  Hawdon-EbbNest201213_20121217_222458_125-GSKma...        12.0      15.0
#
#       dim_1  dim_2     dim_3     dim_4     dim_5     dim_6     dim_7  ...  \
# 0  0.280927    0.0  0.169676  0.231509  0.190414  0.204095  0.484960  ...
# 1  0.318225    0.0  0.322079  0.188719  0.280874  0.118702  0.156187  ...
# 2  0.601878    0.0  0.373245  0.013728  0.435837  0.096302  0.107153  ...
# 3  0.184520    0.0  0.199776  0.348397  0.379622  0.059166  0.012470  ...
# 4  0.005157    0.0  0.133940  0.319355  0.460055  0.008645  0.000000  ...
#
#    dim_1015  dim_1016  dim_1017  dim_1018  dim_1019  dim_1020  dim_1021  \
# 0  0.450947  1.381018  1.067608  0.101641  0.170962  0.619164  0.444076
# 1  0.466702  1.049383  0.776220  0.215639  0.095272  0.534052  0.251640
# 2  0.226496  0.263412  0.618614  0.591965  0.065999  0.587808  0.732815
# 3  0.000000  0.000000  0.751990  0.020382  0.053628  0.330889  1.654205
# 4  0.035401  0.083377  0.787262  0.199003  0.000000  0.391944  1.420127
#
#    dim_1022  dim_1023  dim_1024
# 0  0.017930  0.015840  1.083950
# 1  0.048345  0.062075  1.065395
# 2  0.000000  0.372481  0.596013
# 3  0.000000  0.408940  0.223565
# 4  0.000000  0.251829  0.515901
#
# [5 rows x 1027 columns]
